# %%
# importing necessary library
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
# Reading dataset
df = pd.read_csv("Dataset/Housing.csv")
df.head(2)
# Out:
#       price    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420.0         4          2        3      yes        no       no
# 1  12250000  8960.0         4          4        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished

# %%
# Calculating mean of area
df["area"].mean()
# Out:
# np.float64(5149.913696060037)

# %%
# Check for null values in dataframe
df.isnull().sum()
# Out:
# price                0
# area                12
# bedrooms             0
# bathrooms            0
# stories              0
# mainroad             0
# guestroom            0
# basement             0
# hotwaterheating      0
# airconditioning      0
# parking              0
# prefarea             0
# furnishingstatus     3
# dtype: int64

# %%
# Drop the null values
df.dropna(inplace=True)

# %%
# Check the mean again for area
df["area"].mean()
# Out:
# np.float64(5134.1584905660375)

# %%
# Compute standard deviation of area
df["area"].std()
# Out:
# np.float64(2152.6218324780675)

# %%
# Compute mode for furnishingstatus
df["furnishingstatus"].mode()
# Out:
# 0    semi-furnished
# Name: furnishingstatus, dtype: str

# %%
# Print the data stastical summary for int columns only

# %%
# Lets compute the percentiles
np.percentile(df["price"], 25)
np.percentile(df["price"], 50)
np.percentile(df["price"], 75)
# Out:
# np.float64(5718125.0)

# %%
# skewness for price
df["area"]

# %%
# Kurtosis for price

# %%
# Visualize the skewness asnd kurtosis
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(df["price"],color="red")
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# ## One Sample T-test

# %%
# Suppose a manufacturer claims that the average weight of their new
# chocolate bars is 50 grams. We highly doubt that and want to check this,
# so we drew out a sample of 25 chocolate bars and measured their weight.
# Consider the significance level to be 0.05.
sample = [46.9, 47.8, 48.4, 48.8, 49.0, 49.2, 49.3, 49.4, 49.5, 49.6, 49.7, 49.7,
          49.7, 49.8, 49.9, 50.0, 50.1, 50.2, 50.3, 50.5, 50.7, 51.0, 51.4, 51.9, 52.5]

# %% [raw]
# # Let's define the hypothesis
# H0: Average weight of choocolate = 50gm (Equality sign always in null hypothesis)
#
# H1: Average weight of chocolate ≠ 50 gm (it can be either less than or greater than 50) -> Two tailed test

# %%
# Paste the value of sample and alpha here
sample = [46.9, 47.8, 48.4, 48.8, 49.0, 49.2, 49.3, 49.4, 49.5, 49.6, 49.7, 49.7,
          49.7, 49.8, 49.9, 50.0, 50.1, 50.2, 50.3, 50.5, 50.7, 51.0, 51.4, 51.9, 52.5]

# %%
# Compute the p-value
import scipy.stats as stats
t_test, p_value = stats.ttest_1samp(sample, 50)
t_test, p_value
# Out:
# (np.float64(-0.7841687728913062), np.float64(0.4406125277544944))

# %%
# Check for conditions
if p_value < 0.05:
    print("Reject the null hypothesis, there is enough evidence to support the claim that the average weight of the chocolate bars is not 50 grams.")
else:
    print("Fail to reject the null hypothesis, there is not enough evidence to support the claim that the average weight of the chocolate bars is not 50 grams.")
# Out:
# Fail to reject the null hypothesis, there is not enough evidence to support the claim that the average weight of the chocolate bars is not 50 grams.

# %% [markdown]
# ## Two-Sample t-Test

# %%
# A researcher wants to determine whether there is a significant difference
# in the average age of males and females in a certain community. A random sample
# of 12 males and 12 females was selected.

# %% [raw]
# Let's formulate hypothesis:
#
# H0: Average age of male = Average age of female
#
# H1: Aevarge age of male > Average age of female -> one tailed test

# %%
# here are the samples drawn
male_age = [35, 40, 38, 45, 50, 42, 39, 41, 37, 43, 46, 44]
female_age = [40, 22, 21, 23, 35, 45, 30, 23, 30, 24, 40, 33]
alpha = 0.05

# %%
# Let's perform t_test
t_value, p_value = stats.ttest_ind(male_age, female_age)
t_value, p_value
# Out:
# (np.float64(4.203201778149059), np.float64(0.00036731542883169704))

# %%
# Check for conditions
if p_value < 0.05:
    print("Reject the null hypothesis, which means avg age and female is significantly different.")
else:
    print("Fail to reject the null hypothesis, which means avg age and female is not significantly different.")
# Out:
# Reject the null hypothesis, which means avg age and female is significantly different.
