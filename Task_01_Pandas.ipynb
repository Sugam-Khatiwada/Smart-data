# %%
# Install pandas on your environment

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1.	Write a program to create an empty series.

# %%
# Code here

# %% [markdown]
# ### 2. Create a series using list, provide the custom index, and a name to series like this:
# <img src="attachment:402ad2fd-493e-4998-b429-79222ebba1e5.png" width="400">

# %%
# Code here

# %% [markdown]
# ### 3. Check the attribute of above Series

# %%
# Check the size

# %%
# Check the datatype

# %%
# Find the index of series

# %%
# Find the values

# %%
# Find the name of series

# %%
# Check if the values in series are unique or not

# %%
# Change the name of series to "Marks of Jesse Pinkman"

# %% [markdown]
# ### 4. Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
# Code here 
s1 = pd.Series([1,2,3,4,5,6])
s2 = pd.Series([4,5,6,7,8,9])

# %% [markdown]
# ### 5. Write a Pandas program to compare the elements of the two Pandas Series.

# %%
# Code here (==, >=, =<, !=)

# %% [markdown]
# ### 6. Change the data type of given  column or a Series.

# %%
# Code here
s1 = pd.Series([1.1,3.3,4.4,5.0, 8.0]) # Convert this series to integer type

# %% [markdown]
# #### Download this dataset: `All Batsman runs series in IPL 2008 to 2022.`
# https://drive.google.com/file/d/1p67R1aMplqR-nYUs_FgpGUme5SLy1Z0X/view?usp=drive_link
#
# `After downloading, kindly upload the dataset to the same folder that contains this file.`

# %%
# Read the dataset using read_csv(path)

# %% [markdown]
# ### 7. Find top 10 most run getter from the series.

# %%
# Code here

# %% [markdown]
# ### 8. No of players having runs above 3000.

# %%
# Code here

# %% [markdown]
# ### 9. No of players having runs above mean value

# %%
# Code here

# %% [markdown]
# #### Download this dataset:
# https://drive.google.com/file/d/1vTeAhgxhRcq_AgtP59u7ftk1dCdAuhwf/view?usp=drive_link
#
# `After downloading, kindly upload the dataset to the same folder that contains this file.`

# %% [markdown]
# ### 10. Read `items.csv` making `item_name` as index.

# %%
# Code here

# %% [markdown]
# ### 11. Show numbers of nan values

# %%
# Code here

# %% [markdown]
# ### 12. Item price is given in $, so convert it to rupees without currency symbol.

# %%
# Code here

# %% [markdown]
# ### 13. Fill nan with mean of the series

# %%
# Code here

# %% [markdown]
# ### 14. No of items price lies between [1000 to 2000]

# %%
# Code here
